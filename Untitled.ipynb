# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

# %%
a = np.load('./results/pretrained/predictions.npy')
b = np.load('./results/trained/predictions.npy')
print(a.shape, b.shape)
# Out:
# (1528, 256, 832) (1528, 256, 832)

# %%
index = 21

lst = [a[index], b[index]]
nmax = [np.percentile(i, 95) for i in lst]

fig,ax = plt.subplots(1,2)
fig.set_size_inches(18.5,10.5)
ax[0].imshow(lst[0], cmap='magma', vmax=nmax[1])
ax[1].imshow(lst[1], cmap='magma', vmax=nmax[1])
